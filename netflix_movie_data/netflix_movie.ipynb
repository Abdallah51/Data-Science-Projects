# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
# Start coding here! Use as many cells as you like
#first i will extract movie based on released year between (1990 - 2000)
movies_from_1990_to_2000 = netflix_df[np.logical_and(netflix_df['release_year']>=1990,netflix_df['release_year']<2000)]
#Then create a short list for only movies
short_list = movies_from_1990_to_2000[years_1990_200['type']=='Movie']
#then convert type of duration column to int 
short_list['duration'] = short_list['duration'].astype(int)
#use mode() function to return most repeated movies
duration = short_list[['duration']].mode()
duration = int(duration.iloc[0])
#count number of Action movie
short_movie_count = np.logical_and(short_list['duration']<90,short_list['genre'] == 'Action').sum()
print(duration)
print(short_movie_count)
# Out:
# 94
# 7

# %%
plt.hist(movies_from_1990_to_2000["duration"])
plt.title('Distribution of Movie Durations between 1990 and 2000')
plt.xlabel('Duration / minutes')
plt.ylabel('Number of Movies')
plt.show()
